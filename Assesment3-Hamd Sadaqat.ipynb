# %%
print("Welcome to Python Programming!")
# Task 2

N1 = input("Enter first number: ")
N2 = input("Enter second number: ")

temp = N1
N1 = N2
N2 = temp
print(f"After swapping:\n First number: {N1}\n Second number: {N2}")
# Task 3
# Program to swap two numbers without using a third variable

first_number_str = input("Enter 1st number: ")
second_number_str = input("Enter 2nd number: ")

first_number = int(first_number_str)
second_number = int(second_number_str)


first_number = first_number + second_number
second_number = first_number - second_number
first_number = first_number - second_number



print(f"After swapping:\n First number: {first_number},\n Second number: {second_number}")
# Task 4
celsius = float(input("Enter Celsius: "))
farhrenheit = (9/5) * celsius + 32

print("Temperature:", farhrenheit)
