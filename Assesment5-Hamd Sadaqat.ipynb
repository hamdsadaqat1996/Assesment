# %%
full_name = input('Enter your full name :')
# Out:
# Enter your full name : hamd sadaqat

# %%
print('Hello', full_name,'! welcome to the python assesment')
# Out:
# Hello hamd sadaqat ! welcome to the python assesment

# %%
# string methods

# %%
print('your name in uppercase :', full_name.upper())
# Out:
# your name in uppercase : HAMD SADAQAT

# %%
print('your name in lowercase :', full_name.lower())
# Out:
# your name in lowercase : hamd sadaqat

# %%
print('lentgh of your name :', len(full_name))
# Out:
# lentgh of your name : 12

# %%
print('name with hyphens :', full_name.replace(' ','-'))
# Out:
# name with hyphens : hamd-sadaqat

# %%
#3 typecasting and numeric operations

# %%
birth_year = int(input('enter your birth year :'))
# Out:
# enter your birth year : 2000

# %%
current_year = 2026

# %%
age = current_year-birth_year

# %%
print('You are approximately',age,'years old.')
# Out:
# You are approximately 26 years old.

# %%
# PART 2: LISTS AND INDEXING

# %%
#1 create a list from user input

# %%
fruits = input('Enter your three favourite fruits(separated by comma):')
# Out:
# Enter your three favourite fruits(separated by comma): mango,apple,melon

# %%
fruit_list = fruits.split(',')

# %%
fruit_list
# Out:
# ['mango', 'apple', 'melon']

# %%
#2 list indexing and slicing

# %%
print('first fruit is :',fruit_list[0])
# Out:
# first fruit is : mango

# %%
print('last fruit is :',fruit_list[2])
# Out:
# last fruit is : melon

# %%
print('second fruit is :',fruit_list[1])
# Out:
# second fruit is : apple

# %%
print('first two fruits are:',fruit_list[0:2])
# Out:
# first two fruits are: ['mango', 'apple']

# %%
#3 list methods

# %%
fruit_list.append('melon')

# %%
print('updated fruit list is:',fruit_list)
# Out:
# updated fruit list is: ['mango', 'apple', 'melon', 'melon']

# %%
fruit_list.remove('apple')

# %%
print('updated list:',fruit_list)
# Out:
# updated list: ['mango', 'melon', 'melon']

# %%
print('the length of list is:',len(fruit_list))
# Out:
# the length of list is: 3

# %%
# 3 COMBINING CONCEPTS (OPTIONAL)

# %%
#1 string and list interaction

# %%
letters_list = list(full_name.replace(' ',''))

# %%
print('first three letters are:',letters_list[0:3])
# Out:
# first three letters are: ['h', 'a', 'm']

# %%
print('last three letters are:',letters_list[-3:])
# Out:
# last three letters are: ['q', 'a', 't']

# %%
# simple arithmetic on list of numbers

# %%
numbers = input('enter 5 numbers(separated by space):')
# Out:
# enter 5 numbers(separated by space): 1 2 3 4 5

# %%
numbers_list = list(numbers.split())

# %%
numbers_list
# Out:
# ['1', '2', '3', '4', '5']
