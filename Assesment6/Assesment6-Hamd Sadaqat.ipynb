# %%
#!.

# %%
money = 50

# %%
item_price = 15

# %%
tax = 0.03

# %%
tax_price = item_price*tax

# %%
total_price = item_price + tax_price

# %%
money_left = money - total_price

# %% [markdown]
# print('the money left is :',money_left)

# %%
#2.

# %%
days = int(input("How many days until your birthday? "))
weeks = days / 7
print("Approximate weeks until your birthday:", weeks)
# Out:
# How many days until your birthday?  12
# Approximate weeks until your birthday: 1.7142857142857142

# %%
#3.

# %%
Grade = 65 

if Grade >= 90:
    print("A")
elif Grade >= 80:
    print("B")
elif Grade >= 70:
    print("C")
elif Grade >= 60:
    print("D")
elif Grade >= 0:
    print("F")
else:
    print("Invalid Grade")
# Out:
# D
